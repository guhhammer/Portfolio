# %% [markdown]
# # Class 05: critique of data visualisations
#
# Written analysis of misleading charts shown in class, the Gestalt principles, and a redesign proposal.

# %% [markdown]
# Weekly forecast slide:
#
# The image seems to show a temperature forecast for the week, but we do not know which day of the week we are on, and Thursday is not shown. There is an average of the forecast highs of 64 degrees (it does not say Fahrenheit or Celsius, probably F: an English-speaking country); in the forecast, Wednesday's high is below the average of the other days. Given the colouring of each day's plot there are signs that Wednesday will be a cold day, because of its blue colour. Today is possibly Thursday.

# %% [markdown]
# Analysis of the charts in the slides:
#
#
# I - The perspective of the chart suggests Apple is larger than the others; the same trick is used in the legend.
#
#
# II - The size of the chart is set by the percentage of percentages. The visualisation is strange because it compares things that have little to compare: percentages measured between teams and then compared with other comparisons of teams. The colours do not mean much.
#
#
# III - The colours do not distinguish the diseases much from one another. The chart represents only 75% of the evaluated group. There are no percentages for a more direct comparison.
#
#
# IV - The variation on the y axis per continent seems meaningless. Because of the vertical size of the chart it is hard to read the middle regions against the x-axis measures.
#
#
# V - The title states the value of the last point of the chart; the gaps between the dates on the x axis are inconsistent; we do not know whether they are percentage points; the colours make it a bit harder.
#
#
# VI - It is impossible to tell the size of the world GDP; the chart is messy; comparing percentages does not help visual comparison.
#
#
# VII - Do the 51% include last year's 43%?

# %% [markdown]
# Gestalt Principles:
#
# - Proximity(Proximidade)
#   - Things that are closer to one another are perceived as belonging to a same group.
# - Similarity(Similaridade)
#   - Objects that share shapes, sizes, colors or orientation are perceived as belonging to the same group.
# - Enclosure(Cerceamento)
#   - We observe objects that are enclosed together as belonging to the same group.
# - Closure(Fechamento)
#   - We perceive objects as a whole even though some parts are missing.
# - Continuity(Continuidade)
#   - Our eyes seek the most "natural" and "smooth" path between objects, even though they may not exist.
# - Connection(Conexão)
#   - We tend to perceive connected objects as a group.
#   - Connection is often stronger than color, shape or size.

# %% [markdown]
# Analysis of "market size over time":
#
#
# The chart conveys continuity; the dashed part indicates that the excerpt refers to it. The coloured points are referenced in the text by colour. Both the x axis and the text are divided, giving an idea of who each refers to. The white point indicates that it is only an estimate of the market size up to December 2019. The largest drops and rises of the year have their value in billions of dollars written above the point. The text also has a descriptive continuity, reporting what happened at the beginning of the period covered by the chart.
#
# -
#
# -
#
# Analysis of "time to close deal":
#
# Changes I would make: change the spacing of the values; show the values as a line chart; remove the "19" from the dates on the x axis; change the subtitle to make the idea of the chart clearer; use more contrasting colours; shrink the background line of the y axis.
