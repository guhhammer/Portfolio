# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_csv('http://www.ppgia.pucpr.br/~jean.barddal/datascience/titanic.csv')

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
#df['Age'].apply(lambda x: int(x) if math.isnan(x)!=True else 0)
# Out:
# 0      22
# 1      38
# 2      26
# 3      35
# 4      35
#        ..
# 886    27
# 887    19
# 888     0
# 889    26
# 890    32
# Name: Age, Length: 891, dtype: int64

# %%
df['Age'].hist()

# %%
sns.distplot(df['Age'].dropna())
plt.show()

# %%
# Histograma -> seaborn
sns.distplot(df['Age'].dropna(), kde=False, bins=10)
plt.show()

# %%
# Gráfico de barras
sns.countplot(pd.read_csv('http://www.ppgia.pucpr.br/~jean.barddal/datascience/titanic.csv')['Age'])
plt.show()

# %%
# box-plot
sns.boxplot(pd.read_csv('http://www.ppgia.pucpr.br/~jean.barddal/datascience/titanic.csv')['Age'])
plt.show()
# Whiskers(Bigodes): representam mínimos e máximos "aceitáveis"(Método de Tukey).

# %%
# Violin plot
sns.violinplot(pd.read_csv('http://www.ppgia.pucpr.br/~jean.barddal/datascience/titanic.csv')['Age'])
plt.show()

# %%
# Bar graph
sns.countplot(df['Embarked'])
plt.show()

# %%
# Pie Chart:
df['Embarked'].dropna().value_counts().plot(kind='pie')

# %%
# Comparando as distrinuições de idade por sobrevivência:
sns.boxplot(x=df['Survived'], y=df['Age'])
plt.show()

# %%
# Comparando as distrinuições de sexo por idade:
sns.boxplot(x=df['Sex'], y=df['Age'])
plt.show()

# %%
# Criar a base
df = pd.DataFrame({
    'x' : np.random.normal(10, 1.2, 20000),
    'y' : np.random.normal(10, 1.2, 20000),
    'group' : np.repeat('A', 20000)
})

tmp1 = pd.DataFrame({
    'x' : np.random.normal(14.5, 1.2, 20000),
    'y' : np.random.normal(14.5, 1.2, 20000),
    'group' : np.repeat('B', 20000)
})

tmp2 = pd.DataFrame({
    'x' : np.random.normal(9.5, 1.5, 20000),
    'y' : np.random.normal(15.5, 1.5, 20000),
    'group' : np.repeat('C', 20000)
})

# concatenating the data
df = df.append(tmp1).append(tmp2)

# %%
df.head(5)
# Out:
#            x          y group
# 0   8.898724  10.739542     A
# 1   7.193225  10.310911     A
# 2  10.528322   9.438025     A
# 3   7.320189  10.321922     A
# 4  10.144091   9.037761     A

# %%
df.describe()
# Out:
#                   x             y
# count  60000.000000  60000.000000
# mean      11.333632     13.334749
# std        2.596474      2.722571
# min        3.478008      5.329392
# 25%        9.342116     10.800303
# 50%       10.669957     14.007657
# 75%       13.708171     15.406436
# max       20.101819     20.948073

# %%
# Analisando cada variável de forma individual:
sns.distplot(df['x'])
plt.show()

# %%
sns.distplot(df['y'])
plt.show()

# %%
sns.distplot(df['x'])
sns.distplot(df['y'])
plt.show()

# %%
sns.scatterplot(df['x'], df['y'])
plt.show()

# %%
# mudar o tamanho do marcador:
sns.scatterplot(df['x'], df['y'], s=2)
plt.show()

# %%
# mudar o transparência:
sns.scatterplot(df['x'], df['y'], alpha=0.01)
plt.show()

# %%
# Densidade:
sns.kdeplot(df['x'], df['y'], shade=True)
plt.show()

# %%
# Joint plot:
sns.jointplot(df['x'], df['y'], kind='kde')
plt.show()

# %%
# Amostragem(Sampling)
samp = df.sample(2000)
sns.scatterplot(df['x'], df['y'])
plt.show()

# %%
# Ênfase -> dar mais atenção a um grupo.
df_a = df[df['group'] == "A"]
df_restante = df[df['group'] != "A"]

sns.scatterplot(df_restante['x'], df_restante['y'], color='red')
sns.scatterplot(df_a['x'], df_a['y'], color='green')
plt.show()

# %%
# Facet Grid -> Facetamento.
# Analizar o comportamento de x e y por grupo.
g = sns.FacetGrid(df, col='group', hue='group')
g = g.map(sns.scatterplot, 'x', 'y')
plt.show()

# %%
# Criando nova base de dados
a = np.concatenate([
                    np.random.normal(2, 4, 1000),
                    np.random.normal(4, 4, 1000),
                    np.random.normal(1, 2,  500),
                    np.random.normal(10, 2, 500),
                    np.random.normal(8, 4, 1000),
                    np.random.normal(10, 4, 1000)
])

df = pd.DataFrame({
    'x': np.repeat(range(1,6), 1000),
    'y': a
})

# %%
df.head(5)
# Out:
#    x          y
# 0  1   5.500086
# 1  1   7.187320
# 2  1  -1.234838
# 3  1  12.224084
# 4  1   4.412193

# %%
# Scatterplot
sns.scatterplot(df['x'], df['y'])
plt.show()

# %%
# Strip plot:
sns.stripplot(df['x'], df['y'], jitter=0.3, size=2)
plt.show()

# %%
sns.violinplot(df['x'], df['y'])
sns.stripplot(df['x'], df['y'], jitter=0.3, size=1, color='grey')
plt.show()

# %%
# Swarm plot:
#sns.violinplot(df['x'], df['y'])
sns.swarmplot(df['x'], df['y'])
plt.show()
