# %% [markdown]
# Weekly Forecast slide:
#
# A imagem parece descrever uma previsão de temperatura para a semana, contudo não sabemos em qual dia da semana estamos, e a quinta-feira não é apontada na imagem.  Há uma média das maiores temperaturas previstas de 64 graus(não informou se era fahrenheit ou celsius, possivelmente f -> país de língua inglesa); na previsão, a quarta feira tera a maior temperatura do dia prevista menor do que a média dos outros dias. Devido a coloração dos plots de cada dia da semana, há indícios de que quarta será um dia de frio, devido a sua coloração azul. Possivelmente, hoje é quinta.

# %% [markdown]
# Análise dos gráficos nos slides:
#
#
# I- Perspectiva do gráfico sugere que a apple é maior que os outros; mesma jogada na legenda.
#
#
# II- O tamanho do gráfico é definido pelo percentual dos percentuais. A visualização do gráfico é estranha, pois compara coisas que não possuem muito o que comparar: são percentuais medidos entre times e depois comparados com outras comparações de times. As cores não significam muito.
#
#
# III- As cores não distinguem muito as doenças muito umas das outras. O gráfico só representa 75% do grupo avaliado. Não há percentuais para comparação mais direta.
#
#
# IV- A variação no eixo y por continente parece não ter um sentido.
# Devido ao tamanho vertical do gráfico, fica difícil visualizar as regiões do meio com as medidas no eixo x.
#
#
# V-  O título afirma o valor do último ponto no gráfico; a diferença entre as datas no eixo x não possui uma consistência; não sabemos se são pontos percentuais; as cores dificultam um pouco.
#
#
# VI- não dá para saber o tamanho do pib mundial, o gráfico é bagunçado; comparação entre percentuais, não facilita comparações visuais.
#
#
# VII - Os 51% compreendem os 43% do ano passado?

# %% [markdown]
# Gestalt Principles:
#
# - Proximity(Proximidade)
#   - Things that are closer to one another are perceived as belonging to a same group.
# - Similarity(Similaridade)
#   - Objects that share shapes, sizes, colors or orientation are perceived as belonging to the same group.
# - Enclosure(Cerceamento)
#   - We observe objects that are enclosed together as belonging to the same group.
# - Closure(Fechamento)
#   - We perceive objects as a whole even though some parts are missing.
# - Continuity(Continuidade)
#   - Our eyes seek the most "natural" and "smooth" path between objects, even though they may not exist.
# - Connection(Conexão)
#   - We tend to perceive connected objects as a group.
#   - Connection is often stronger than color, shape or size.

# %% [markdown]
# Análise market size over time:
#
#
# O Gráfico expressa uma ideia de continuidade, a parte tracejada incida que o excerto se refere a ela. Os pontos coloridos são indicados no texto como referência visual por meio de cores. Tanto o eixo x como o texto são divididos dando a ideia de quem a eles se refere. O ponto em branco indica que é apenas uma estimativa do tamanho do mercado até Dezembro de 2019. As maiores quedas e altas do ano possuem o valor em de bilhões de dólares, explicitado acima do ponto. O texto também possui uma continuidade descritiva, relatando o que aconteceu no começo do período tratado pelo gráfico.
#
# -
#
# -
#
# Análise Time to close Deal:
#
# Mudanças a serem feitas:
# Eu mudaria o espaçamento dos valores; representaria os valores em um gráfico de linhas; tiraria o 19 das datas no eixo x; mudaria o subtítulo para melhor explicitar a ideia do gráfico colocaria cores mais conflitantes; diminuir a linha de fundo do eixo y.
